# %% [markdown]
# <a href="https://colab.research.google.com/github/DaffaFathir/Machine-Learning-Task/blob/main/Tugas%204/Dataset_Diabetes_Daffa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama : Daffa Fathir Fajri
NIM : 1103213149
Lecture : 4
Dataset : Diabetes.csv

# %%
# Mengimpor library yang diperlukan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Mengimpor dataset dari URL
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
diabetes = pd.read_csv(url, header=None)

# Menambahkan nama kolom
diabetes.columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Menampilkan lima baris pertama dari dataset
print(diabetes.head())

# Visualisasi histogram dari semua fitur
diabetes.hist(figsize=(12, 10))
plt.suptitle('Histogram untuk Setiap Fitur', fontsize=16)
plt.show()

# Visualisasi boxplot untuk kolom Glucose dan Insulin
plt.figure(figsize=(10, 6))
sns.boxplot(data=diabetes[['Glucose', 'Insulin']], orient='v')
plt.title('Boxplot untuk Glucose dan Insulin')
plt.ylabel('Nilai')
plt.show()

# Visualisasi scatter plot antara Glucose dan BMI
plt.figure(figsize=(10, 6))
sns.scatterplot(data=diabetes, x='Glucose', y='BMI', hue='Outcome')
plt.title('Scatter Plot Glucose vs BMI dengan Warna Berdasarkan Outcome')
plt.xlabel('Glucose')
plt.ylabel('BMI')
plt.show()

# Visualisasi distribusi usia berdasarkan Outcome
plt.figure(figsize=(10, 6))
sns.histplot(data=diabetes, x='Age', hue='Outcome', multiple='stack')
plt.title('Distribusi Usia dengan Warna Berdasarkan Outcome')
plt.xlabel('Usia')
plt.ylabel('Frekuensi')
plt.show()

# Visualisasi pairplot untuk melihat korelasi antar fitur
plt.figure(figsize=(12, 10))
sns.pairplot(diabetes, hue='Outcome')
plt.suptitle('Pairplot untuk Melihat Korelasi Antar Fitur dengan Warna Berdasarkan Outcome', fontsize=16)
plt.show()

# Visualisasi correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(diabetes.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Antar Fitur')
plt.show()

# Visualisasi countplot untuk Outcome
plt.figure(figsize=(8, 6))
sns.countplot(data=diabetes, x='Outcome')
plt.title('Countplot untuk Outcome')
plt.xlabel('Outcome')
plt.ylabel('Jumlah')
plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
